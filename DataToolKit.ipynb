# %%
THEORY QUESTIONS
'''
Q1 What is NumPy, and why is it widely used in Python
>> A numpy stand for Numerical Python, it is a library of python,it is widely usd because it provide large functionality on arrays(multi dimensional)
and on matrices,and large operation on them with high speed

Q2 How does broadcasting work in NumPy
Broadcasting is the method NumPy uses to perform arithmetic operations on arrays of different shapes without explicitly copying data or writing loops.

Q3 What is a Pandas DataFrame
A Pandas DataFrame is a two-dimensional, tabular data structure in Python provided by the pandas library.

Q4 Explain the use of the groupby() method in Pandas
The groupby() method in Pandas is used to split data into groups based on one or more columns, and then apply operations
 (like aggregation, transformation, or filtering) on each group.

Q5 Why is Seaborn preferred for statistical visualizations
Seaborn is a Python data visualization library built on top of Matplotlib.
It is specifically designed for statistical data visualization and works seamlessly with Pandas DataFrames.

Q6 What are the differences between NumPy arrays and Python lists
Python list can contain multiple data types but an numpy array can have only one data type in a array

Q7 What is a heatmap, and when should it be used
A heatmap is a data visualization technique that represents values in a matrix (rows × columns) format, where the values are shown using color gradients.
Darker/brighter colors = higher values.
Lighter/paler colors = lower values.

Q8 What does the term “vectorized operation” mean in NumPy
In NumPy, a vectorized operation means applying an operation directly on entire arrays (vectors, matrices) without using explicit Python loops.

Q9 How does Matplotlib differ from Plotly
Matplotlib = Best for static, highly customizable plots (foundation of visualization in Python).
Plotly = Best for interactive, modern visualizations (great for dashboards and data exploration).

Q10 What is the significance of hierarchical indexing in Pandas

Q11 What is the role of Seaborn’s pairplot() function
pairplot() is a function in Seaborn that creates a grid of plots showing relationships between all pairs of numerical variables in a dataset, along with their distributions.

Q12 What is the purpose of the describe() function in Pandas
The describe() function provides descriptive statistics of the numerical (or categorical) columns in a DataFrame or Series.
It is mainly used for exploratory data analysis (EDA) to understand the dataset quickly.

Q13 Why is handling missing data important in Pandas
Missing data refers to empty, null, or NaN values in a dataset,if there wil be missing data then in analysic it will be difficult

Q14 What are the benefits of using Plotly for data visualization
Plotly is widely used because it offers many advantages for modern, interactive data visualization

Q15 How does NumPy handle multidimensional arrays
A multidimensional array is an array with more than one dimension, e.g., 2D , 3D etc.
In NumPy, these are represented using the ndarray object.
Ex a=np.array([1,2],[3,4])

Q16 What is the role of Bokeh in data visualization
Bokeh is a Python library for interactive and web-ready data visualization.
Focused on creating interactive plots, dashboards, and applications for modern web browsers.
Works well with large datasets.

Q17 Explain the difference between apply() and map() in Pandas
Use map() when you want to transform each element in a Series.
Use apply() when you want to perform more complex operations on a Series or aggregate/transform rows/columns in a DataFrame.

Q18 What are some advanced features of NumPy
Advanced features of NumPy include:
Broadcasting and vectorized operations
Advanced indexing and slicing
Multidimensional arrays and tensors
Linear algebra, random number generation, FFT
Masking and conditional operations
Structured arrays for heterogeneous data
Highly optimized for speed and memory efficiency

Q19 How does Pandas simplify time series analysis
Datetime-aware data types and indexes
Easy slicing and selection by date/time
Resampling, frequency conversion, and aggregation

Q20 What is the role of a pivot table in Pandas
A pivot table is a data summarization tool that allows you to aggregate data and reorganize it based on one or more categorical variables.

Q21 Why is NumPy’s array slicing faster than Python’s list slicing
Because numpy array have Contiguous Memory Storage,NumPy slicing returns a view of the original array (does not copy data),Vectorized Operations

Q22 What are some common use cases for Seaborn
Visualizing distributions of data
Exploring relationships between variables
Comparing categorical data
Creating correlation heatmaps
Performing regression/trend analysis
Conducting multivariate analysis
Plotting time series trends
'''

# %%
# Q1 How do you create a 2D NumPy array and calculate the sum of each row
import numpy as np
a=np.array([[1,2,3],[4,5,6]])
a
a.sum(axis=1)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# Write a Pandas script to find the mean of a specific column in a DataFrame
import pandas as pd
a={
    "Age": [12,87,45,23,10],
    'Salary':[6700,5600,20000,20000,5600]
}
df=pd.DataFrame(a)
df
df['Age'].mean()
df['Salary'].mean()
# Out:
# np.float64(35.4)

# %%
# Q3 Create a scatter plot using Matplotlib
import matplotlib.pyplot as plt
a=np.random.rand(50)
b=np.random.rand(50)
plt.scatter(a,b,c='r',marker='*')

# %%
# Q4 How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap

# %%
# Q5 Generate a bar plot using Plotly
import plotly.express as px
data={
    'Fruits': ['Apples','Banana','Kiwi','Orange'],
    'Price':[20,30,10,50]
}
px.bar(data,x='Fruits',y='Price',title='Fruit Price')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Q6 Create a DataFrame and add a new column based on an existing column
data={
    'Salary':[2300,4000,1000,2000]
}
df=pd.DataFrame(data)
df['Dept']=['IT','Civil','CSE','EE']
df
# Out:
#    Salary   Dept
# 0    2300     IT
# 1    4000  Civil
# 2    1000    CSE
# 3    2000     EE

# %%
# Q7 Write a program to perform element-wise multiplication of two NumPy arrays
a=np.array([[1,2,3,4],[5,6,7,8]])
b=np.array([[10,20,30,40],[50,60,70,80]])
np.multiply(a,b)
# Out:
# array([[ 10,  40,  90, 160],
#        [250, 360, 490, 640]])

# %%
# Create a line plot with multiple lines using Matplotlib
x=[1,2,3,4]
y1=[5,9,7,8]
y2=[2,0,6,4]

plt.plot(x,y1,label='Line1',color='r',linestyle='-',marker='o')
plt.plot(x,y2,label='Line2',color='b',linestyle='--',marker='x')
plt.title('Line plot')
plt.legend()
plt.show()

# %%
# Q9 Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold
d={
    'Salary':[5000,1000,2000,6000],
    'age':[30,25,28,54]
}
df=pd.DataFrame(d)
threshold=2000
df[df['Salary']>2000]
# Out:
#    Salary  age
# 0    5000   30
# 3    6000   54

# %%
# Q10 Create a histogram using Seaborn to visualize a distribution
import seaborn as sns
sns.get_dataset_names()
df=sns.load_dataset('tips')
sns.histplot(df,bins=50)
plt.show()

# %%
# Perform matrix multiplication using NumPy
a=np.matrix([[1,2,3,4],[5,5,5,5]])
b=np.matrix([[1,6,7,8],[8,9,2,8]])
c=np.multiply(a,b)
c
# Out:
# matrix([[ 1, 12, 21, 32],
#         [40, 45, 10, 40]])

# %%
# Use Pandas to load a CSV file and display its first 5 rows
df=pd.read_csv('FILE_NAME.csv')
df.head()

# %%
# Create a 3D scatter plot using Plotly
a=np.random.rand(50)
b=np.random.rand(50)
c=np.random.rand(50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
